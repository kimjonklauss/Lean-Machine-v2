# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjonklauss/Lean-Machine-v2/blob/main/LeanMachinev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://github.com/kimjonklauss/Lean-Machine-v2/blob/main/Archivo%20B%202.csv"

df = pd.read_csv(url)

df.head()
